# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as mlt
import seaborn as sns
import numpy
import matplotlib.pyplot as plot
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
df_info1=pd.read_csv(r'/home/payal/Desktop/odi_info.csv')

# %%
df_scorecard1=pd.read_csv(r'/home/payal/Desktop/odi_scorecard.csv')

# %%
f,ax = plt.subplots(figsize=(25, 15))
sns.heatmap(df_scorecard1.corr(), annot=True, linewidths=0.5,linecolor="red", fmt= '.1f',ax=ax)
plt.show()

# %%
df_scorecard1['name'].unique()
# Out:
# array(['DA Warner', 'Mohammad Nawaz (3)', 'Hasan Ali', ..., 'CC Blake',
#        'TCR Kimber', 'J Butler'], dtype=object)

# %%
df_dhoni=df_scorecard1[df_scorecard1['name']=='MS Dhoni']

# %%
df_dhoni
# Out:
#        match-id team-name  innings      name  batting-position  over-batsman  \
# 788     1022361     India        1  MS Dhoni                 5          33.4
# 934     1022375     India        2  MS Dhoni                 5           9.1
# 1205    1030219     India        2  MS Dhoni                 5          19.4
# 1218    1030221     India        2  MS Dhoni                 5          18.5
# 1242    1030223     India        2  MS Dhoni                 4           8.5
# ...         ...       ...      ...       ...               ...           ...
# 34092    903593     India        2  MS Dhoni                 5          40.1
# 34109    903595     India        1  MS Dhoni                 5          18.1
# 34130    903597     India        2  MS Dhoni                 4          23.2
# 34149    903599     India        1  MS Dhoni                 6          44.6
# 34173    903601     India        2  MS Dhoni                 6          24.6
#
# ...

# %%
x = df_dhoni.loc[:,'balls-played'].values
y = df_dhoni.loc[:, 'runs-scored'].values

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
linearRegressor = LinearRegression()

# %%
xTrain=xTrain.reshape(-1, 1)
xTest=xTest.reshape(-1, 1)
yTrain=yTrain.reshape(-1, 1)
yTest=yTest.reshape(-1, 1)

# %%
linearRegressor.fit(xTrain, yTrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
yPrediction = linearRegressor.predict(xTest)

# %%
plot.scatter(xTrain, yTrain, color = 'red')
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plot.xlabel('balls played')
plot.ylabel('runs scored')
plot.show()

# %%
#  mean_absolute_error(yTest, yPrediction)

# %%
plot.scatter(xTest, yTest, color = 'red')
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plot.xlabel('balls played')
plot.ylabel('runs scored')
plot.show()
